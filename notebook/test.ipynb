# %%
import pandas as pd
import json

# %%
data = pd.read_csv('../dataset/data_train_eli - Sheet1 (1).csv')
data
# Out:
#      G001   G002   G003   G004   G005   G006   G007   G008   G009   G010  \
# 0      ya  tidak  tidak  tidak  tidak  tidak  tidak  tidak  tidak     ya
# 1      ya  tidak  tidak  tidak  tidak  tidak  tidak  tidak  tidak  tidak
# 2      ya  tidak  tidak  tidak  tidak  tidak  tidak  tidak  tidak  tidak
# 3      ya  tidak  tidak  tidak  tidak  tidak  tidak  tidak  tidak  tidak
# 4      ya  tidak  tidak  tidak  tidak  tidak  tidak  tidak  tidak  tidak
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 67     ya  tidak     ya  tidak  tidak  tidak  tidak  tidak  tidak     ya
# 68     ya  tidak     ya  tidak  tidak  tidak  tidak  tidak  tidak  tidak
# 69  tidak     ya  tidak  tidak     ya  tidak  tidak  tidak  tidak     ya
# 70  tidak  tidak  tidak  tidak     ya  tidak  tidak  tidak  tidak     ya
# 71  tidak  tidak  tidak  tidak     ya  tidak  tidak  tidak  tidak     ya
#
#    Kode Kerusakan
# 0            K001
# 1            K001
# 2            K001
# ...

# %%
# data['Kode Kerusakan']

# total = data['Kode Kerusakan'].count()
# per_data = data['Kode Kerusakan'].value_counts()

# data_ = {'K011': 5,
#  'K025': 4,
#  'K024': 4,
#  'K001': 3,
#  'K028': 3,
#  'K022': 3,
#  'K014': 3,
#  'K012': 3,
#  'K032': 3,
#  'K007': 3,
#  'K005': 3,
#  'K010': 2,
#  'K009': 2,
#  'K031': 2,
#  'K030': 2,
#  'K029': 2,
#  'K004': 2,
#  'K023': 2,
#  'K006': 2,
#  'K021': 2,
#  'K020': 2,
#  'K016': 2,
#  'K015': 2,
#  'K008': 2,
#  'K017': 2,
#  'K019': 1,
#  'K018': 1,
#  'K002': 1,
#  'K026': 1,
#  'K027': 1,
#  'K003': 1,
#  'K013': 1}

# data_div = []
# for k,v in data_.items():
#     data_div.append({
#         "name":k,
#         "count":v / total
#     })

# data_div
